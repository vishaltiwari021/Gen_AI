# %%
# This is first Interaction with jupyter

# %%
print("hello vishal")
# Out:
# hello vishal

# %%
print("hello world")
# Out:
# hello world

# %%
print(1+2)
# Out:
# 3

# %%
print("1+2")
# Out:
# 1+2

# %%
print("5*9")
# Out:
# 5*9

# %%
pip i numpy
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: unknown command "i"

# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 832.0 kB/s eta 0:00:13
#    -- ------------------------------------- 0.8/11.0 MB 865.1 kB/s eta 0:00:12
#    --- ------------------------------------ 1.0/11.0 MB 870.1 kB/s eta 0:00:12
#    ------- -------------------------------- 2.1/11.0 MB 1.1 MB/s eta 0:00:09
#    -------- ------------------------------- 2.4/11.0 MB 1.1 MB/s eta 0:00:08
#    ---------- ----------------------------- 2.9/11.0 MB 1.2 MB/s eta 0:00:07
#    ----------- ---------------------------- 3.1/11.0 MB 1.2 MB/s eta 0:00:07
#    ------------ --------------------------- 3.4/11.0 MB 1.2 MB/s eta 0:00:07
#    ------------- -------------------------- 3.7/11.0 MB 1.2 MB/s eta 0:00:07
# ...

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
